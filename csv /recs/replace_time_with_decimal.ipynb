# %%
import pandas as pd

# %%
df = pd.read_csv('recs_50_99.csv', sep=';', decimal=',')

# %%
df.head()
# Out:
#    rec_id  session_id paradigm stimulus stimulus_status stimulus_side  \
# 0   50002          50  chooser    R8-F1              pr          left
# 1   50002          50  chooser    R8-M4             NaN         right
# 2   50005          50  chooser    R8-M2             NaN          left
# 3   50005          50  chooser    R8-F2              di         right
# 4   60002          60  partner   R10-F1              es           NaN
#
#    stimulus_novelty  objects  object_side  object_novelty  start_time  \
# 0                 0      NaN          NaN               0  1467199.30
# 1                 1      NaN          NaN               0  1467199.30
# 2                 0      NaN          NaN               0  3014350.23
# 3                 0      NaN          NaN               0  3014350.23
# 4                 0      NaN          NaN               0  1763534.31
#
#      end_time
# 0  1790154.23
# 1  1790154.23
# 2  3361553.72
# 3  3361553.72
# 4  2357518.93

# %%
df.to_csv('recs_50_99.csv')
