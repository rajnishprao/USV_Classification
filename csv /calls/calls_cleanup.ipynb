# %%
import pandas as pd
import os

# %%
#df = pd.read_csv('calls_75001.csv')
#df = pd.read_csv('calls_75002.csv')
#df = pd.read_csv('calls_75003.csv')
df = pd.read_csv('calls_146001.csv')

# %%
df.head()
# Out:
#    USV_id  Rec_id  type_id    Nlx_time  duration  contact emitter emitter_sex  \
# 0  282292  146001        5  1239686.14     43.40        0       U           -
# 1  282293  146001        8  1242569.49     78.31        0       I           f
# 2  282294  146001        8  1246239.21     51.77        0       I           f
# 3  282295  146001        5  1246686.43     29.94        0       I           f
# 4  282296  146001        7  1250752.88     48.43        0       R           m
#
#    side recipient_sex  Nlx_adjusted  onset_phase  rat_intensity  rat_cluster  \
# 0   NaN           NaN    1239686.14          NaN            NaN         2411
# 1   NaN           NaN    1242569.49          NaN         2411.0         2411
# 2   NaN           NaN    1246239.21          NaN         2411.0         2411
# 3   NaN           NaN    1246686.43          NaN         2411.0         2411
# 4   NaN           NaN    1250752.88          NaN         2414.0         2414
#
#   emitter_cluster
# 0               I
# 1               I
# 2               I
# 3               I
# 4               R

# %%
df['emitter'].replace({'I': 'R17', 'L': 'R17-M2', 'R': 'R17-M1', 'U': 'unknown'}, inplace=True)

# %%
df['emitter_sex'].replace({'m':'male', 'f':'female'}, inplace=True)

# %%
df.head()
# Out:
#    USV_id  Rec_id  type_id    Nlx_time  duration  contact  emitter  \
# 0  282292  146001        5  1239686.14     43.40        0  unknown
# 1  282293  146001        8  1242569.49     78.31        0      R17
# 2  282294  146001        8  1246239.21     51.77        0      R17
# 3  282295  146001        5  1246686.43     29.94        0      R17
# 4  282296  146001        7  1250752.88     48.43        0   R17-M1
#
#   emitter_sex  side recipient_sex  Nlx_adjusted  onset_phase  rat_intensity  \
# 0           -   NaN           NaN    1239686.14          NaN            NaN
# 1      female   NaN           NaN    1242569.49          NaN         2411.0
# 2      female   NaN           NaN    1246239.21          NaN         2411.0
# 3      female   NaN           NaN    1246686.43          NaN         2411.0
# 4        male   NaN           NaN    1250752.88          NaN         2414.0
#
#    rat_cluster emitter_cluster
# 0         2411               I
# 1         2411               I
# 2         2411               I
# 3         2411               I
# 4         2414               R

# %%
df.to_csv('clean_calls_146001.csv')

# %%
#df = pd.read_csv('calls_71001.csv')
#df = pd.read_csv('calls_71002.csv')
#df = pd.read_csv('calls_71003.csv')
#df = pd.read_csv('calls_71004.csv')

# %%
# df['emitter'].replace({'I': 'R11', 'S': 'F1-R11', 'U': 'unknown'}, inplace=True)

# %%
# df['emitter_sex'].replace({'m':'male', 'f':'female'}, inplace=True)

# %%
# df.head()

# %%
#df.to_csv('clean_calls_71003.csv')
